# %%
import os
os.chdir('/media/data3/users/luongdth/FastPitch')

# %%
# !python scripts/prepare_vivos_filelist.py --vivos-dir "data/vivos"
# Out:
# Created filelists/vivos_train.txt with 11660 samples.
# Created filelists/vivos_test.txt with 760 samples.

# %%
# !bash scripts/prepare_vivos_dataset.sh
# Out:
# DLL 2026-09-03 00:32:16.319101 - PARAMETER dataset_path : data/vivos
# DLL 2026-09-03 00:32:16.319257 - PARAMETER wav_text_filelists : ['filelists/vivos_train.txt', 'filelists/vivos_test.txt']
# DLL 2026-09-03 00:32:16.319320 - PARAMETER extract_mels : True
# DLL 2026-09-03 00:32:16.319369 - PARAMETER extract_pitch : True
# DLL 2026-09-03 00:32:16.319469 - PARAMETER save_alignment_priors : True
# DLL 2026-09-03 00:32:16.319514 - PARAMETER log_file : preproc_log.json
# DLL 2026-09-03 00:32:16.319555 - PARAMETER n_speakers : 1
# DLL 2026-09-03 00:32:16.319635 - PARAMETER max_wav_value : 32768.0
# DLL 2026-09-03 00:32:16.319687 - PARAMETER sampling_rate : 22050
# DLL 2026-09-03 00:32:16.319728 - PARAMETER filter_length : 1024
# DLL 2026-09-03 00:32:16.319766 - PARAMETER hop_length : 256
# DLL 2026-09-03 00:32:16.319848 - PARAMETER win_length : 1024
# DLL 2026-09-03 00:32:16.319888 - PARAMETER mel_fmin : 0.0
# DLL 2026-09-03 00:32:16.319927 - PARAMETER mel_fmax : 8000.0
# ...

# %%
# !python scripts/update_filelist_with_pitch.py --input filelists/vivos_train.txt --output filelists/vivos_with_pitch_train.txt
# !python scripts/update_filelist_with_pitch.py --input filelists/vivos_test.txt --output filelists/vivos_with_pitch_test.txt
# Out:
# Updated 11660 lines, skipped 0
# Saved to filelists/vivos_with_pitch_train.txt
# Updated 760 lines, skipped 0
# Saved to filelists/vivos_with_pitch_test.txt

# %%
# %cd /media/data3/users/luongdth/FastPitch
# !bash scripts/train_vivos.sh
# Out:
# /media/data3/users/luongdth/FastPitch
# /media/data3/users/luongdth/anaconda3/envs/fastpitch/lib/python3.10/site-packages/torch/distributed/launch.py:207: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# DLL 2026-09-03 10:11:00.355486 - PARAMETER | output :  ./output_vivos
# DLL 2026-09-03 10:11:00.355709 - PARAMETER | dataset_path :  data/vivos
# DLL 2026-09-03 10:11:00.355832 - PARAMETER | log_file :  ./output_vivos/nvlog.json
# DLL 2026-09-03 10:11:00.355891 - PARAMETER | epochs :  1000
# DLL 2026-09-03 10:11:00.355938 - PARAMETER | epochs_per_checkpoint :  50
# DLL 2026-09-03 10:11:00.355982 - PARAMETER | checkpoint_path :
# ...
