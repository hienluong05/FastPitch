# %%
import os
os.chdir('/media/data3/users/luongdth/FastPitch')

# %%
# !python scripts/prepare_vivos_filelist.py --vivos-dir "data/vivos"
# Out:
# python: can't open file '/media/data3/users/luongdth/FastPitch/prepare_vivos_filelist.py': [Errno 2] No such file or directory
